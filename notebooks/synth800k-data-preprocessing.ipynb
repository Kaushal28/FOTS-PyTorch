# %%
password = "<password>"
# !git clone https://kaushal28:{password}@github.com/Kaushal28/FOTS-PyTorch.git
# Out:
# Cloning into 'FOTS-PyTorch'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (190/190), done.
# remote: Total 264 (delta 125), reused 194 (delta 60), pack-reused 0
# Receiving objects: 100% (264/264), 14.69 MiB | 15.15 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# %%writefile config.json
#
# {
#     "data_dir": "../input/small-synth800k/content/SynthText",
#     "output_dir": "./gt",
#     "batch_size": 2,
#     "num_workers": 4
# }
# Out:
# Writing config.json

# %%
# !cp -r ./FOTS-PyTorch/* .
# !python data_helpers/data_preprocessor.py -c config.json
# Out:
# Loading ground truth matrix...
# 100it [02:58,  1.79s/it]

# %%
# !ls gt
# Out:
# geo  image  score  train.csv  training_mask

# %%
# !zip -r -qq gt.zip gt/*
# !rm -rf gt
